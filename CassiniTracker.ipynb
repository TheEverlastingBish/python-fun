# %%
import json
import pandas as pd
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener

consumer_key = 'JFvjfTSXeBVXe8RJ9ar2sAANT'
consumer_secret = 'unwiimEmw6cE8CNBD0RifIzsy7zrPxaXlycw921Gak6ZvPnYHt'
access_token = '74800383-WXJGqRVuJSKaVOD309uSj6s4u4I5rAC91i8Oa673X'
access_secret = '6pg65FgxgV2z4810FL3z1c2rM44pVtblGmPpi57VsRSGw'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

print("Authenticated!")
# Out:
# Authenticated!

# %%
class MyStreamListener(StreamListener):

    def on_status(self, status):
        print(status.text)

myStreamListener = MyStreamListener()
myStream = Stream(auth, listener=MyStreamListener())

# %%
myStream.filter(track=['cassini'], async=True)
# Out:
# RT @astrokiwi: Loss of signal within half a minute of prediction: we know Saturn's atmosphere that well.
#
# More discoveries coming!…
# RT @RealRonHoward: Cassini Vanishes Into Saturn, Its Mission Celebrated and Mourned via @NYTimes https://t.co/0L8IxWIik5
# RT @CassiniSaturn: Every time we see Saturn in the night sky, we'll remember. We'll smile. And we'll want to go back. #GrandFinale…
# RT @MetricButtload: Mostly I feel sorry for the monkey pilot on Cassini.
# @elakdawalla
# Why did you block @Barackoboehner ? He's almost a rocket scientist and followed #Cassini for 20 years.
# Don't like white people?
# RT @elakdawalla: Cassini: The dying of the light https://t.co/mCi1SPrNkj https://t.co/jONAoW7OGu
# RT @ChrisJZullo: Donald Trump's border wall, which has no chance of stopping illegal immigration, will cost more than our entire space prog…
# RT @AstroKatie: Planetbot, we are sad about Cassini too. #GrandFinale https://t.co/dhb8nT3eUI
# ...
